# %% [markdown]
# ## Assingment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Inspect your Data:
#
# Before you begin exploring the data, write some code in chunks to preview and summarize the data frame using some of the method’s we’ve used in class. You can consider following questions in your exploration:
#
# 1. What is the total size of the data frame?
#
# 2. What type of data is each variable (numeric, character, logical, date)?
#
# 3. Do any variables have missing values? Why might that be?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# For Loading the dataset into a Pandas DataFrame
df = pd.read_csv('/content/drive/MyDrive/Assignment_data_third_semester/WorldCupMatches.csv')

# Question 1: What is the total size of the data frame?
total_size_of_frame = df.shape
size = df.size
print(f"size of the data frame in the form of (Rows,Columns): {total_size_of_frame}")

#Actual total Size
print(f"Actual total Size of the DataFrame is: {size} ")
# Out:
# size of the data frame in the form of (Rows,Columns): (4572, 20)
# Actual total Size of the DataFrame is: 91440

# %%
# Question 2: What type of data is each variable (numeric, character, logical, date)?
data_type = df.dtypes
print("\n\nData types of each variable:")
print(data_type)
# Out:
# Data types of each variable:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
# Question 3: Do any variables have missing values? Why might that be?
miss_value = df.isnull().sum()
print("\n\nMissing Values in the Datasets are as follows:\n")
print(miss_value)

print("\n\nThe main reason behind the missing value maybe:\n ")
print("1. Error during the collection of the data.")
print("2. There might be some system errors.")
print("3. Some attributes doesn't have any values.\n\n\n")

# null_value = df.isnull()
# print(null_value)
# Out:
# Missing Values in the Datasets are as follows:
#
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64
#
#
# The main reason behind the missing value maybe:
#
# 1. Error during the collection of the data.
# 2. There might be some system errors.
# 3. Some attributes doesn't have any values.

# %%
#Columns of the Datasets
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
#Information of the datasets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
df
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %% [markdown]
# # Data Cleaning and Summary Statistics [3]
#
# • Data Cleaning: Based on your previous inspection you can explore following options but are not
# limited to clean your data:
# 1. If found any missing values use appropriate data imputations techniques discussed in your workshops to fill the missing values. Please justify why did you pick particular techniques.
# 2. If found any duplicates remove those observations.
# 3. Perform more data cleaning as you think is required for your particular dataset.Justify your action.
#
# # • Summary Statistics:
#  The next step in EDA is to examine the measures of variability and central
# tendency for the variables in the data set. For this step you can do the following:
# Split the Dataset into numeric column and Categorical Column.
# – For Numeric Column:
# 1. Use descriptive function to gather basic statistical information about the variables such as:
# min., max., range, mean, median, Variance, standard deviation.
# 2. Observe the output and explain if anything interesting note it.
# #For Categorical Column:
# 1. For character variables, what are the unique values in the variable?
# 2. Figure out the mode of such variables.
# 3. If any date variables, what time period do the observations in these data frames span.

# %%
#Data Cleaning

#filling the missing values
#By observing my Daatsets, i only found float64 & object as datatype.
#For float64, i used mean of the columns for filling out the missing value
numeric_columns = df.select_dtypes(include=["float64"]).columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
# For object datatype, i use mode of the columns for filling the missing space.
categorical_columns = df.select_dtypes(include=["object"]).columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

#Displaying the data after filling out the missing values
df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
# droping the rows having missing values.
df = df.dropna()

# Removing duplicates
df = df.drop_duplicates()
df
# Out:
#             Year              Datetime        Stage             Stadium  \
# 0    1930.000000  13 Jul 1930 - 15:00       Group 1             Pocitos
# 1    1930.000000  13 Jul 1930 - 15:00       Group 4      Parque Central
# 2    1930.000000  14 Jul 1930 - 12:45       Group 2      Parque Central
# 3    1930.000000  14 Jul 1930 - 14:50       Group 3             Pocitos
# 4    1930.000000  15 Jul 1930 - 16:00       Group 1      Parque Central
# ..           ...                   ...          ...                 ...
# 832  2014.000000  29 Jun 2014 - 13:00   Round of 16    Estadio Castelao
# 833  2014.000000  29 Jun 2014 - 17:00   Round of 16    Arena Pernambuco
# 834  2014.000000  01 Jul 2014 - 13:00   Round of 16  Arena de Sao Paulo
# 835  2014.000000  01 Jul 2014 - 17:00   Round of 16    Arena Fonte Nova
# 852  1985.089202  27 May 1934 - 16:30   Round of 16      Estadio Azteca
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
# Reset index after dropping rows
df = df.reset_index(drop=True)

# %%
# Display the first few rows of the cleaned DataFrame
print(df.head())
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
#Summary Satistics

#Question 1:
# Spliting the Dataset into numeric and categorical columns
numeric_columns = df.select_dtypes(include=["float64"]).columns
categorical_columns = df.select_dtypes(include=["object"]).columns

# For Numeric Columns
numeric_summary = df[numeric_columns].describe()
print("\nSummary Statistics for Numeric Columns:")
print(numeric_summary)

#unique values for numeric column
for col in numeric_columns:
  numeric_unique_values = df[col].unique()
  print(f"\n Numeric Unique values for \n {col}: {numeric_unique_values}")
# Out:
# Summary Statistics for Numeric Columns:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   837.000000       837.000000       837.000000     837.000000
# mean   1984.536546         1.824147         1.021532   44860.187097
# std      22.286527         1.618210         1.071383   23522.924572
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   29800.000000
# 50%    1990.000000         2.000000         1.000000   41123.000000
# 75%    2002.000000         3.000000         2.000000   60960.000000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            837.000000            837.000000  8.370000e+02  8.370000e+02
# mean               0.718888              0.427035  1.086069e+07  5.678124e+07
# std                0.941432              0.674687  2.750155e+07  1.069690e+08
# ...

# %%
# For Categorical Columns
#Question 3
categorical_summary = df[categorical_columns].describe(include='all')
print("\nSummary Statistics for Categorical Columns:")
print(categorical_summary)
# Out:
# Summary Statistics for Categorical Columns:
#                     Datetime        Stage         Stadium          City  \
# count                    837          837             837           837
# unique                   602           23             181           151
# top     27 May 1934 - 16:30   Round of 16  Estadio Azteca  Mexico City
# freq                       9           65              20            24
#
#        Home Team Name Away Team Name Win conditions                Referee  \
# count             837            837            837                    837
# unique             78             83             43                    366
# top            Brazil         Mexico                 Ravshan IRMATOV (UZB)
# freq               79             38            780                     10
#
#                              Assistant 1               Assistant 2  \
# count                                837                       837
# ...

# %%
# Unique values for character variables
for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"\nUnique values for {col}: {unique_values}")
# Out:
# Unique values for Datetime: ['13 Jul 1930 - 15:00 ' '14 Jul 1930 - 12:45 ' '14 Jul 1930 - 14:50 '
#  '15 Jul 1930 - 16:00 ' '16 Jul 1930 - 14:45 ' '17 Jul 1930 - 12:45 '
#  '17 Jul 1930 - 14:45 ' '18 Jul 1930 - 14:30 ' '19 Jul 1930 - 12:50 '
#  '19 Jul 1930 - 15:00 ' '20 Jul 1930 - 13:00 ' '20 Jul 1930 - 15:00 '
#  '21 Jul 1930 - 14:50 ' '22 Jul 1930 - 14:45 ' '26 Jul 1930 - 14:45 '
#  '27 Jul 1930 - 14:45 ' '30 Jul 1930 - 14:15 ' '27 May 1934 - 16:30 '
#  '31 May 1934 - 16:30 ' '01 Jun 1934 - 16:30 ' '03 Jun 1934 - 16:30 '
#  '07 Jun 1934 - 18:00 ' '10 Jun 1934 - 17:30 ' '04 Jun 1938 - 17:00 '
#  '05 Jun 1938 - 17:00 ' '05 Jun 1938 - 17:30 ' '05 Jun 1938 - 18:30 '
#  '09 Jun 1938 - 18:00 ' '12 Jun 1938 - 17:00 ' '14 Jun 1938 - 18:00 '
#  '16 Jun 1938 - 18:00 ' '19 Jun 1938 - 17:00 ' '24 Jun 1950 - 15:00 '
#  '25 Jun 1950 - 15:00 ' '28 Jun 1950 - 15:00 ' '29 Jun 1950 - 15:00 '
#  '29 Jun 1950 - 15:30 ' '01 Jul 1950 - 15:00 ' '02 Jul 1950 - 15:00 '
# ...

# %%
#Question-4
# Mode for character variables
categorical_mode = df[categorical_columns].mode().iloc[0]
print("\nMode for Categorical Columns:")
print(categorical_mode)
# Out:
# Mode for Categorical Columns:
# Datetime                  27 May 1934 - 16:30
# Stage                              Round of 16
# Stadium                         Estadio Azteca
# City                              Mexico City
# Home Team Name                          Brazil
# Away Team Name                          Mexico
# Win conditions
# Referee                  Ravshan IRMATOV (UZB)
# Assistant 1                BERANEK Alois (AUT)
# Assistant 2           KOCHKAROV Bakhadyr (KGZ)
# Home Team Initials                         BRA
# Away Team Initials                         MEX
# Name: 0, dtype: object

# %%
# Extracting the 'Datetime' column from the DataFrame
time_period = df['Datetime'].min(), df['Datetime'].max()

# Displaying the time period for the 'Datetime' column
print(f"\nTime period for 'Datetime': {time_period}")
# Out:
# Time period for 'Datetime': ('01 Jul 1950 - 15:00 ', '31 May 2002 - 20:30 ')

# %% [markdown]
# # Visualize the Data: Make Interpret and Save your Charts [5].
# Now that you have a basic understanding of the dataset, make some charts/figures to explore the variables
# in the data and their potential relationships. You may use base pandas plotting functions or matplotlib or
# seaborn or any package to make your figures, but you must make at least figures of at least two different
# variables for each category below:
# # • Univariate Analysis: [3]
#  Pick any of the two variables of your choice and perform the following:
# – Make Chart:For your selected two variables:
# 1. Make Line Chart or Bar chart or Pie chart, whichever best fits your dataset.
# 2. For your selected two variables plot a figure to analyze Skewness and Modality of Distributions
# present in dataset.
# 3. For your selected two variables plot a figure to analyze Outliers present in dataset.
# – Interpret a Chart: For all the figure write a short description and interpretation of your chart.
# While doing that make sure you address at least the following questions:
# 1. Describe what variables you are plotting and why.
# 2. Describe the primary relationship or information reader will gain from your visualization.

# %%
df
# Out:
#             Year              Datetime        Stage             Stadium  \
# 0    1930.000000  13 Jul 1930 - 15:00       Group 1             Pocitos
# 1    1930.000000  13 Jul 1930 - 15:00       Group 4      Parque Central
# 2    1930.000000  14 Jul 1930 - 12:45       Group 2      Parque Central
# 3    1930.000000  14 Jul 1930 - 14:50       Group 3             Pocitos
# 4    1930.000000  15 Jul 1930 - 16:00       Group 1      Parque Central
# ..           ...                   ...          ...                 ...
# 832  2014.000000  29 Jun 2014 - 13:00   Round of 16    Estadio Castelao
# 833  2014.000000  29 Jun 2014 - 17:00   Round of 16    Arena Pernambuco
# 834  2014.000000  01 Jul 2014 - 13:00   Round of 16  Arena de Sao Paulo
# 835  2014.000000  01 Jul 2014 - 17:00   Round of 16    Arena Fonte Nova
# 836  1985.089202  27 May 1934 - 16:30   Round of 16      Estadio Azteca
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
#Question 1
# Calculating total goals for home and away teams
total_home_goals = df['Home Team Goals'].sum()
print("Total Home Team Goal: ",total_home_goals)

total_away_goals = df['Away Team Goals'].sum()
print("Total Away Team Goal: ",total_away_goals)
print("\n\n")

# Creating a bar chart
plt.figure(figsize=(8, 6))
bar1 = plt.bar('Home Team Goals', total_home_goals, color='blue', label='Home Team Goals')
bar2 = plt.bar('Away Team Goals', total_away_goals, color='green', label='Away Team Goals')
plt.title('Total Goals Scored by Home and Away Teams')
plt.xlabel('Team')
plt.ylabel('Total Goals')
plt.legend()
plt.show()
# Out:
# Total Home Team Goal:  1526.8110328638497
# Total Away Team Goal:  855.0223004694835

# %%
# Creating distribution plots
plt.figure(figsize=(12, 5))

# Distribution plot for Home Team Goals
plt.subplot(1, 2, 1)

sns.histplot(df['Home Team Goals'],bins=10,color="green",kde=True,line_kws= {'linewidth': '2'}).lines[0].set_color('red')

plt.title('Distribution of Home Team Goals')
plt.xlabel('Goals')
plt.ylabel('Frequency')

#skewness for Home Team Goals
home_goals_skew = df['Home Team Goals'].skew()
print(f"The skewness of the Home goals is:{home_goals_skew} ")


# Distribution plot for Away Team Goals
plt.subplot(1, 2, 2)

sns.histplot(df['Away Team Goals'],bins=10,color='orange',kde=True,line_kws= {'linewidth': '2'}).lines[0].set_color('blue')

plt.title('Distribution of Away Team Goals')
plt.xlabel('Goals')
plt.ylabel('Frequency')

#skewness for Away Team Goals
away_goals_skew = df['Away Team Goals'].skew()
print(f"The skewness of the Away goals is: {away_goals_skew}\n\n")

plt.tight_layout()
plt.show()
# Out:
# The skewness of the Home goals is:1.339104373314723
# The skewness of the Away goals is: 1.4020340264891735

# %%
# Creating boxplots to identify outliers
plt.figure(figsize=(8, 6))

# Boxplot for Home Team Goals
plt.subplot(1, 2, 1)
plt.boxplot(df['Home Team Goals'])
plt.title('Boxplot of Home Team Goals')
plt.grid()

# Boxplot for Away Team Goals
plt.subplot(1, 2, 2)
plt.boxplot(df['Away Team Goals'])
plt.title('Boxplot of Away Team Goals')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # • Bi-variate Analysis: [2]
# Split the dataset into numeric and categorical column, store the Numeric
# Column in different dataframe and for that dataframe:
# – Make Chart:
# 1. Explore correlation visualization with scatter plot between the variables.
# {Hint: Explore the seborn pairplot function.}
# 2. Explore the correlation visualization with the heatmap.
# – Interpret Chart: For all the figure write a short description and interpretation of your chart.
# While doing that make sure you address at least the following questions:
# 1. Describe what variables you are plotting and why.
# 2. Describe the primary relationship or information reader will gain from your visualization.
# • Save Chart: All the chart/figure made above in Univariate and Bi-variate Analysis must be save in
# ”.png” format and use in the report.

# %%
#Spliting the Numeric and Catagorical coulumns
#Numeric columns
print("The numerical columns are:\n")
print(numeric_columns)
# Out:
# The numerical columns are:
#
# Index(['Year', 'Home Team Goals', 'Away Team Goals', 'Attendance',
#        'Half-time Home Goals', 'Half-time Away Goals', 'RoundID', 'MatchID'],
#       dtype='object')

# %%
#Catagorical Coulumns
print("The Catagorial Columns: \n")
print(categorical_columns)
# Out:
# The Catagorial Columns:
#
# Index(['Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Away Team Name', 'Win conditions', 'Referee', 'Assistant 1',
#        'Assistant 2', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
#Question 1
#Correlation visualization according to the scatter plot between the variables.

numeric_data = df.select_dtypes(include='number')
categorical_data = df.select_dtypes(exclude='number')

sns.pairplot(numeric_data)
plt.title('Pairplot of Numeric Columns')
plt.show()

# %%
#Scatter plot between Home Teams Goals vs Away Team Goals
sns.scatterplot(data=numeric_data, x='Home Team Goals', y='Away Team Goals')
plt.title('Scatter Plot: Home Team Goals vs Away Team Goals')
plt.xlabel('Home Team Goals')
plt.ylabel('Away Team Goals')
plt.show()

# %%
#Question 2
#correlation visualization with the heatmap.
correlation_matrix = numeric_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation visualization with the Heatmap of Numeric Columns')
plt.show()
